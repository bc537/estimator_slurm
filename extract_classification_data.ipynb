# %%
import os
import pandas as pd

# Define the base directory
base_dir = './data/classification'

# Initialize an empty list to store the data
data = []

# Walk through the directory structure
for root, dirs, files in os.walk(base_dir):
    # Initialize variables to store scores
    test_score = None
    training_score = None
    
    for file in files:
        if file in ['test_scores', 'training_scores']:
            # Extract variable values from the directory structure
            parts = root.split('/')
            classification_id = parts[-6]
            encoding = parts[-5]
            ansatz = parts[-4]
            split = int(parts[-3][5:])  # Extract integer value following 'split'
            num_ansatz_layers = int(parts[-2][1])  # Extract integer following 'a'
            datapoint = int(parts[-1][1:])  # Extract integer value from p{1}

            # Read the score from the file
            with open(os.path.join(root, file), 'r') as f:
                score = float(f.read().strip())

            # Assign score to the appropriate variable
            if file == 'test_scores':
                test_score = score
            elif file == 'training_scores':
                training_score = score
    
    # Append the data to the list if both scores are found
    if test_score is not None and training_score is not None:
        if classification_id == "15225294" or classification_id == "15225524" or classification_id == "15247727":
            hamiltonian = "IIIIZZIIII"
        elif classification_id == "15228132" or classification_id == "15241886" or classification_id == "15241961" or classification_id == "15247742" or classification_id == "15247745" or classification_id == "15247746" or classification_id == "15247747" or classification_id == "15247748":
            hamiltonian = "ZZZZZZZZZZ"
        else:
            hamiltonian = None
        data.append({
            'LSFJOBID': classification_id,
            'encoding': encoding,
            'ansatz': ansatz,
            'split': split,
            'num_ansatz_layers': num_ansatz_layers,
            'datapoint': datapoint,
            'hamiltonian': hamiltonian,
            'training_score': training_score,
            'test_score': test_score
        })

# Create a DataFrame from the data
df = pd.DataFrame(data)

# Sort the DataFrame by all columns except training and test scores
df.sort_values(by=['encoding', 'ansatz', 'split', 'num_ansatz_layers', 'datapoint'], inplace=True)



# Save the DataFrame to an Excel file (append mode)
excel_file = f"{base_dir}/scores.xlsx"
if os.path.exists(excel_file):
    existing_df = pd.read_excel(excel_file, engine='openpyxl')
    df = pd.concat([existing_df, df], ignore_index=True)

df.to_excel(excel_file, index=False)
# Out:
# here

# %%
import pandas as pd

base_dir = './data/classification'

# Load the Excel file into a DataFrame
excel_file = f'{base_dir}/scores.xlsx'
df = pd.read_excel(excel_file, engine='openpyxl')

# Display the DataFrame
print(df)
# Out:
#       LSFJOBID encoding           ansatz  split  num_ansatz_layers  datapoint  \
# 0     15225294   ry_rxx  ry_crx_pairwise      1                  1          1
# 1     15225294   ry_rxx  ry_crx_pairwise      1                  1          2
# 2     15225294   ry_rxx  ry_crx_pairwise      1                  1          3
# 3     15225294   ry_rxx  ry_crx_pairwise      1                  1          4
# 4     15225294   ry_rxx  ry_crx_pairwise      1                  1          5
# ...        ...      ...              ...    ...                ...        ...
# 4454  15241961   ry_rxx   ry_cz_pairwise      5                  5         96
# 4455  15241961   ry_rxx   ry_cz_pairwise      5                  5         97
# 4456  15241961   ry_rxx   ry_cz_pairwise      5                  5         98
# 4457  15241961   ry_rxx   ry_cz_pairwise      5                  5         99
# 4458  15241961   ry_rxx   ry_cz_pairwise      5                  5        100
#
# ...

# %%
df.head()
# Out:
#    LSFJOBID encoding           ansatz  split  num_ansatz_layers  datapoint  \
# 0  15225294   ry_rxx  ry_crx_pairwise      1                  1          1
# 1  15225294   ry_rxx  ry_crx_pairwise      1                  1          2
# 2  15225294   ry_rxx  ry_crx_pairwise      1                  1          3
# 3  15225294   ry_rxx  ry_crx_pairwise      1                  1          4
# 4  15225294   ry_rxx  ry_crx_pairwise      1                  1          5
#
#   hamiltonian  training_score  test_score
# 0  IIIIZZIIII        0.714286    0.523810
# 1  IIIIZZIIII        0.726190    0.619048
# 2  IIIIZZIIII        0.678571    0.523810
# 3  IIIIZZIIII        0.690476    0.619048
# 4  IIIIZZIIII        0.690476    0.523810

# %%
df.columns
# Out:
# Index(['LSFJOBID', 'encoding', 'ansatz', 'split', 'num_ansatz_layers',
#        'datapoint', 'hamiltonian', 'training_score', 'test_score'],
#       dtype='object')

# %%
import pandas as pd

# Assuming df is your DataFrame
def find_missing_rows(df):
    # Group by the specified columns
    grouped = df.groupby(['encoding', 'ansatz', 'split', 'num_ansatz_layers', 'hamiltonian'])
    
    # List to store missing rows
    missing_rows = []
    # Dictionary to store the count of missing datapoints for each combination
    missing_counts = {}
    
    # Iterate over each group
    for name, group in grouped:
        # Create a set of expected datapoints
        expected_datapoints = set(range(1, 101))
        # Get the actual datapoints in the group
        actual_datapoints = set(group['datapoint'])
        # Find the missing datapoints
        missing_datapoints = expected_datapoints - actual_datapoints
        
        # Append the missing rows to the list
        for missing in missing_datapoints:
            missing_rows.append({
                'LSFJOBID': None,  # Assuming missing rows won't have an LSFJOBID
                'encoding': name[0],
                'ansatz': name[1],
                'split': name[2],
                'num_ansatz_layers': name[3],
                'datapoint': missing,
                'hamiltonian': name[4]
            })
        
        # Store the count of missing datapoints for this combination
        missing_counts[name] = len(missing_datapoints)
    
    # Convert the list of missing rows to a DataFrame
    missing_df = pd.DataFrame(missing_rows)
    
    # Print the missing rows
    print(missing_df)
    
    # Print the count of missing datapoints for each combination
    for combination, count in missing_counts.items():
        if count >0:
            print(f"Combination {combination} has {count} missing datapoints.")
    
    return missing_df

# %%
missing_df = find_missing_rows(df)
# Out:
#    LSFJOBID encoding           ansatz  split  num_ansatz_layers  datapoint  \
# 0      None   ry_rxx  ry_crx_pairwise      1                  3         26
# 1      None   ry_rxx   ry_cz_pairwise      1                  1          1
# 2      None   ry_rxx   ry_cz_pairwise      1                  1          2
# 3      None   ry_rxx   ry_cz_pairwise      1                  1          3
# 4      None   ry_rxx   ry_cz_pairwise      1                  1          6
# 5      None   ry_rxx   ry_cz_pairwise      1                  1          7
# 6      None   ry_rxx   ry_cz_pairwise      1                  1          8
# 7      None   ry_rxx   ry_cz_pairwise      1                  1          9
# 8      None   ry_rxx   ry_cz_pairwise      1                  3          4
# 9      None   ry_rxx   ry_cz_pairwise      1                  3          5
# 10     None   ry_rxx   ry_cz_pairwise      1                  3          6
# ...

# %%
missing_df.columns
# Out:
# Index(['LSFJOBID', 'encoding', 'ansatz', 'split', 'num_ansatz_layers',
#        'datapoint', 'hamiltonian'],
#       dtype='object')

# %%
import pandas as pd

# Assuming missing_df is your DataFrame with missing data
def update_lsfjobid(missing_df, jobid_mapping):
    # Iterate over each row and update the LSFJOBID based on the unique combination
    for i, row in missing_df.iterrows():
        key = (row['encoding'], row['ansatz'], row['split'], row['num_ansatz_layers'], row['datapoint'], row['hamiltonian'])
        if key in jobid_mapping:
            missing_df.at[i, 'LSFJOBID'] = jobid_mapping[key]
        else:
            raise ValueError(f"No LSFJOBID found for combination: {key}")
    
    return missing_df

# %%
import pandas as pd

# Assuming missing_df is your DataFrame with missing data
def construct_tuples_and_prompt(missing_df):
    # Create a set of unique combinations
    unique_combinations = set(
        (row['encoding'], row['ansatz'], row['split'], row['num_ansatz_layers'], row['datapoint'], row['hamiltonian'])
        for _, row in missing_df.iterrows()
    )
    
    # Dictionary to store the job IDs
    jobid_mapping = {}
    
    # Prompt for each unique combination
    for combination in unique_combinations:
        print(f"Enter LSFJOBID for combination {combination}:")
        jobid = input()
        jobid_mapping[combination] = jobid
    
    return jobid_mapping

# Example usage
# jobid_mapping = construct_tuples_and_prompt(missing_df)

# Now you can use the update_lsfjobid function from the previous example
# updated_missing_df = update_lsfjobid(missing_df, jobid_mapping)

# %%
jobid_mapping = construct_tuples_and_prompt(missing_df)
# Out:
# Enter LSFJOBID for combination ('ry_rxx', 'ry_cz_pairwise', 1, 3, 10, 'ZZZZZZZZZZ'):
